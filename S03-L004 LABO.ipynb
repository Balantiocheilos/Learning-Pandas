# %%
import pandas as pd

# %%
fuel=pd.read_csv('./data/fuel.csv',low_memory=False,
                usecols=['Vehicle ID','Year','Make','Model','Class',
                        'Fuel Type','Combined MPG (FT1)'])
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class Fuel Type  Combined MPG (FT1)
# 0             Minicompact Cars   Regular                20.0
# 1             Minicompact Cars   Regular                20.0
# 2                  Two Seaters   Regular                21.0
# 3                  Two Seaters   Regular                21.0
# 4  Special Purpose Vehicle 2WD   Regular                17.0

# %%
fuel['Combined KPL']=fuel['Combined MPG (FT1)']*1.609/3.78
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class Fuel Type  Combined MPG (FT1)  Combined KPL
# 0             Minicompact Cars   Regular                20.0      8.513228
# 1             Minicompact Cars   Regular                20.0      8.513228
# 2                  Two Seaters   Regular                21.0      8.938889
# 3                  Two Seaters   Regular                21.0      8.938889
# 4  Special Purpose Vehicle 2WD   Regular                17.0      7.236243

# %%
fuel.insert(loc=5,column='liters per m',value=100/fuel.Year)

# %%
del fuel['liters per gm']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6776/1592601838.py in <module>
# ----> 1 del fuel.Model
#
# AttributeError: Model

# %%
fuel.head()
# Out:
#    Vehicle ID  Year        Make               Model  \
# 0       26587  1984  Alfa Romeo           GT V6 2.5
# 1       27705  1984  Alfa Romeo           GT V6 2.5
# 2       26561  1984  Alfa Romeo  Spider Veloce 2000
# 3       27681  1984  Alfa Romeo  Spider Veloce 2000
# 4       27550  1984  AM General   DJ Po Vehicle 2WD
#
#                          Class  liters per km Fuel Type  Combined MPG (FT1)  \
# 0             Minicompact Cars      11.746426   Regular                20.0
# 1             Minicompact Cars      11.746426   Regular                20.0
# 2                  Two Seaters      11.187073   Regular                21.0
# 3                  Two Seaters      11.187073   Regular                21.0
# 4  Special Purpose Vehicle 2WD      13.819325   Regular                17.0
#
#    Combined KPL
# 0      8.513228
# 1      8.513228
# 2      8.938889
# 3      8.938889
# 4      7.236243

# %%
fuel.drop(labels='Combined MPG (FT1)',axis=1)
# Out:
#        Vehicle ID  Year        Make               Model  \
# 0           26587  1984  Alfa Romeo           GT V6 2.5
# 1           27705  1984  Alfa Romeo           GT V6 2.5
# 2           26561  1984  Alfa Romeo  Spider Veloce 2000
# 3           27681  1984  Alfa Romeo  Spider Veloce 2000
# 4           27550  1984  AM General   DJ Po Vehicle 2WD
# ...           ...   ...         ...                 ...
# 31679       32060  2012  Mitsubishi              Lancer
# 31680       32063  2012  Mitsubishi          Lancer AWD
# 31681       32065  2012  Mitsubishi    Lancer Evolution
# 31682       32064  2012  Mitsubishi    Lancer Evolution
# 31683       32106  2012   Mitsubish                 NaN
#
#                              Class  liters per km Fuel Type  Combined KPL
# 0                 Minicompact Cars      11.746426   Regular      8.513228
# 1                 Minicompact Cars      11.746426   Regular      8.513228
# ...

# %%
fuel.drop(labels=1)
# Out:
#        Vehicle ID  Year        Make               Model  \
# 0           26587  1984  Alfa Romeo           GT V6 2.5
# 2           26561  1984  Alfa Romeo  Spider Veloce 2000
# 3           27681  1984  Alfa Romeo  Spider Veloce 2000
# 4           27550  1984  AM General   DJ Po Vehicle 2WD
# 5           28426  1984  AM General   DJ Po Vehicle 2WD
# ...           ...   ...         ...                 ...
# 31679       32060  2012  Mitsubishi              Lancer
# 31680       32063  2012  Mitsubishi          Lancer AWD
# 31681       32065  2012  Mitsubishi    Lancer Evolution
# 31682       32064  2012  Mitsubishi    Lancer Evolution
# 31683       32106  2012   Mitsubish                 NaN
#
#                              Class  liters per km Fuel Type  \
# 0                 Minicompact Cars      11.746426   Regular
# 2                      Two Seaters      11.187073   Regular
# 3                      Two Seaters      11.187073   Regular
# ...

# %%
fuel.drop(index=3)
# Out:
#        Vehicle ID  Year        Make               Model  \
# 0           26587  1984  Alfa Romeo           GT V6 2.5
# 1           27705  1984  Alfa Romeo           GT V6 2.5
# 2           26561  1984  Alfa Romeo  Spider Veloce 2000
# 4           27550  1984  AM General   DJ Po Vehicle 2WD
# 5           28426  1984  AM General   DJ Po Vehicle 2WD
# ...           ...   ...         ...                 ...
# 31679       32060  2012  Mitsubishi              Lancer
# 31680       32063  2012  Mitsubishi          Lancer AWD
# 31681       32065  2012  Mitsubishi    Lancer Evolution
# 31682       32064  2012  Mitsubishi    Lancer Evolution
# 31683       32106  2012   Mitsubish                 NaN
#
#                              Class  liters per km Fuel Type  \
# 0                 Minicompact Cars      11.746426   Regular
# 1                 Minicompact Cars      11.746426   Regular
# 2                      Two Seaters      11.187073   Regular
# ...

# %%
fuel.drop(columns='Fuel Type')
# Out:
#        Vehicle ID  Year        Make               Model  \
# 0           26587  1984  Alfa Romeo           GT V6 2.5
# 1           27705  1984  Alfa Romeo           GT V6 2.5
# 2           26561  1984  Alfa Romeo  Spider Veloce 2000
# 3           27681  1984  Alfa Romeo  Spider Veloce 2000
# 4           27550  1984  AM General   DJ Po Vehicle 2WD
# ...           ...   ...         ...                 ...
# 31679       32060  2012  Mitsubishi              Lancer
# 31680       32063  2012  Mitsubishi          Lancer AWD
# 31681       32065  2012  Mitsubishi    Lancer Evolution
# 31682       32064  2012  Mitsubishi    Lancer Evolution
# 31683       32106  2012   Mitsubish                 NaN
#
#                              Class  liters per km  Combined MPG (FT1)  \
# 0                 Minicompact Cars      11.746426                20.0
# 1                 Minicompact Cars      11.746426                20.0
# 2                      Two Seaters      11.187073                21.0
# ...

# %%
fuel.drop(columns)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_6776/4143888933.py in <module>
# ----> 1 fuel.drop(labels=5, level=5)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
# ...

# %%
fuel.drop(columns='Combined MPG (FT1)', inplace=True)

# %%
fuel.drop(index=3,inplace=True)

# %%
fuel
# Out:
#        Vehicle ID  Year        Make               Model  \
# 0           26587  1984  Alfa Romeo           GT V6 2.5
# 1           27705  1984  Alfa Romeo           GT V6 2.5
# 2           26561  1984  Alfa Romeo  Spider Veloce 2000
# 4           27550  1984  AM General   DJ Po Vehicle 2WD
# 5           28426  1984  AM General   DJ Po Vehicle 2WD
# ...           ...   ...         ...                 ...
# 31679       32060  2012  Mitsubishi              Lancer
# 31680       32063  2012  Mitsubishi          Lancer AWD
# 31681       32065  2012  Mitsubishi    Lancer Evolution
# 31682       32064  2012  Mitsubishi    Lancer Evolution
# 31683       32106  2012   Mitsubish                 NaN
#
#                              Class  liters per km Fuel Type  Combined KPL
# 0                 Minicompact Cars      11.746426   Regular      8.513228
# 1                 Minicompact Cars      11.746426   Regular      8.513228
# ...
